# %% [markdown]
# # Aligning a nifti segmentation mask and a Dicom serie

# %%
import nifti2png as n2p
import numpy as np
import pydicom
import nibabel as nib
import matplotlib.pyplot as plt
import cv2
import os

# Set the path to the folder containing the DICOM files
dicom_folder = '.../S900006_ct/data/D01_sample/dcm_ct/ABTRY00000000_000_000/'  
nifti_folder = '.../.../D01_sample/output/ABTRY00000000_000_000/pancreas.nii.gz'
output_folder = 'demo'
os.makedirs(output_folder, exist_ok=True)


n2p.full_process(dicom_folder, nifti_folder, output_folder,)

# %%
data = plt.imread('demo/D01_sample/ABTRY00000000_000_000/overlay/ABTRY00000000_000_000_062.png')
plt.imshow(data)
